# %%
# a place to experiment with the demos of:

# %%
# %pip install wbdata
import wbdata
import geopandas as gp

countries = gp.read_file("zip://../data/countries.zip")

countries
# Out:
#      iso3                           status color_code  \
# 0     UGA                     Member State        UGA
# 1     UZB                     Member State        UZB
# 2     IRL                     Member State        IRL
# 3     ERI                     Member State        ERI
# 4    None                     UK Territory        GBR
# ..    ...                              ...        ...
# 251   SVK                     Member State        SVK
# 252   MLI                     Member State        MLI
# 253   ARM                     Member State        ARM
# 254   ALB                     Member State        ALB
# 255   GIB  UK Non-Self-Governing Territory        GBR
#
#                                            name   continent           region  \
# 0                                        Uganda      Africa   Eastern Africa
# 1                                    Uzbekistan        Asia     Central Asia
# 2                                       Ireland      Europe  Northern Europe
# ...

# %%
import ogr
